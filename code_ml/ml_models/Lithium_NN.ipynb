# %%
# Import dependencies
import pandas as pd
import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
import sklearn as skl
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
# Show TensorFlow version
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.16.1

# %%
# Connect notebook to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Read CSV file from google drive into a DataFrame and display it
df=pd.read_csv("/content/drive/MyDrive/Project_4/df_cleaned.csv")
df
# Out:
#        IDUSGS PLAYTYPE   WELLTYPE   FORMSIMPLE       TDS   LATITUDE  \
# 0          63    Shale  Shale Gas    Marcellus   54800.0  40.441658
# 1          64    Shale  Shale Gas    Marcellus   26100.0  40.441658
# 2          65    Shale  Shale Gas    Marcellus   41700.0  40.441658
# 3          67    Shale  Shale Gas    Marcellus   38200.0  41.270892
# 4          68    Shale  Shale Gas    Marcellus   82600.0  41.270892
# ...       ...      ...        ...          ...       ...        ...
# 60653  115711    Shale  Tight Oil  Three Forks  328018.0  47.740170
# 60654  115712    Shale  Tight Oil       Bakken  283801.0  47.740170
# 60655  115713    Shale  Tight Oil  Three Forks  311627.0  47.740170
# 60656  115714    Shale  Tight Oil  Three Forks  324452.0  47.740170
# 60657  115715    Shale  Tight Oil  Three Forks  317760.0  47.740170
#
#         LONGITUDE         STATE     COUNTY           PROVINCE  ...  FeTot  \
# 0      -79.986932  Pennsylvania  Allegheny  Appalachian Basin  ...  27.40
# 1      -79.986932  Pennsylvania  Allegheny  Appalachian Basin  ...   6.47
# 2      -79.986932  Pennsylvania  Allegheny  Appalachian Basin  ...  43.50
# 3      -76.659691  Pennsylvania   Lycoming  Appalachian Basin  ...  15.70
# 4      -76.659691  Pennsylvania   Lycoming  Appalachian Basin  ...  35.20
# ...           ...           ...        ...                ...  ...    ...
# 60653 -103.395280  North Dakota   McKenzie    Williston Basin  ...    NaN
# 60654 -103.395280  North Dakota   McKenzie    Williston Basin  ...    NaN
# 60655 -103.395280  North Dakota   McKenzie    Williston Basin  ...    NaN
# 60656 -103.395280  North Dakota   McKenzie    Williston Basin  ...    NaN
# 60657 -103.395280  North Dakota   McKenzie    Williston Basin  ...    NaN
#
#                K      Li        Mg          Na    SO4     Sr      Zn  \
# 0         0.0000  21.500   295.000  12000.0000  105.0  736.5  0.0839
# 1         0.0000  12.500   188.000   6920.0000  116.0  215.0  0.0321
# 2         0.0000  19.800   278.000  12700.0000   69.3   67.0  0.0657
# 3        53.4000     NaN   164.000  11100.0000    NaN  417.0  0.0570
# 4        59.6000     NaN   367.000  19800.0000    NaN    1.0  0.0100
# ...          ...     ...       ...         ...    ...    ...     ...
# 60653  8210.6430  76.351  1385.385  91108.1811    NaN    NaN     NaN
# 60654  7350.4804  62.469  1263.860  77498.2787    NaN    NaN     NaN
# 60655  8718.9209  76.351  1288.165  84992.9209    NaN    NaN     NaN
# 60656  8914.4124  76.351  1312.470  88809.2111    NaN    NaN     NaN
# 60657  8797.1175  76.351  1263.860  86901.0660    NaN    NaN     NaN
#
#        CHARGEBAL  BASIN_CATEGORY
# 0          -10.5     Appalachian
# 1           -3.0     Appalachian
# 2           -4.8     Appalachian
# 3           -1.4     Appalachian
# 4          -13.8     Appalachian
# ...          ...             ...
# 60653       -2.1       Williston
# 60654       -3.1       Williston
# 60655       -2.3       Williston
# 60656       -2.4       Williston
# 60657       -2.5       Williston
#
# [60658 rows x 34 columns]

# %%
# Give me a list of every unique value in the Basin_category column

unique_values = df['BASIN_CATEGORY'].unique().tolist()
print(unique_values)
# Out:
# ['Appalachian', 'Permian', 'Oklahoma Platform', 'Gulf Coast', 'Williston', 'Michigan', 'Pacific', 'Illinois', 'Great Plains', 'Anadarko', 'Rocky Mountain', 'Fort Worth']

# %%
# Create a new dataframe named df_gulf that has only rows from df that have the value 'Gulf Coast' in BASIN_CATEGORY

df_gulf = df[df["BASIN_CATEGORY"] == "Gulf Coast"]
df_gulf
# Out:
#        IDUSGS     PLAYTYPE                  WELLTYPE FORMSIMPLE       TDS  \
# 224      1013  Sedimentary  Conventional Hydrocarbon    Edwards  171306.0
# 225      1014  Sedimentary  Conventional Hydrocarbon    Edwards  109938.0
# 226      1016  Sedimentary  Conventional Hydrocarbon    Edwards  108400.0
# 227      1017  Sedimentary  Conventional Hydrocarbon    Edwards   71265.0
# 228      1018  Sedimentary  Conventional Hydrocarbon    Edwards   71138.0
# ...       ...          ...                       ...        ...       ...
# 60342  115346  Sedimentary  Conventional Hydrocarbon     Wilcox   89456.0
# 60343  115347  Sedimentary  Conventional Hydrocarbon     Wilcox  108691.0
# 60344  115348  Sedimentary  Conventional Hydrocarbon     Wilcox   95434.0
# 60345  115350  Sedimentary  Conventional Hydrocarbon     Wilcox  108019.0
# 60346  115351  Sedimentary  Conventional Hydrocarbon     Wilcox  136668.0
#
#        LATITUDE  LONGITUDE      STATE     COUNTY  \
# 224    29.03000  -97.85000      Texas     Karnes
# 225    29.01000  -97.90000      Texas     Karnes
# 226    28.63367  -97.98417      Texas        Bee
# 227    28.59220  -98.03431      Texas        Bee
# 228    28.74400  -97.90900      Texas     Karnes
# ...         ...        ...        ...        ...
# 60342  31.59986  -92.15279  Louisiana    LaSalle
# 60343  31.48436  -92.00514  Louisiana  Catahoula
# 60344  31.49222  -92.00539  Louisiana  Catahoula
# 60345  31.47478  -91.87311  Louisiana  Catahoula
# 60346  31.37490  -91.80560  Louisiana  Catahoula
#
#                                 PROVINCE  ...    FeTot        K     Li  \
# 224                         Western Gulf  ...      NaN  2410.00  124.0
# 225                         Western Gulf  ...      NaN  1510.00   77.3
# 226                         Western Gulf  ...      NaN  1271.00    NaN
# 227                         Western Gulf  ...      NaN   494.00   83.9
# 228                         Western Gulf  ...      NaN   340.00    NaN
# ...                                  ...  ...      ...      ...    ...
# 60342  Louisiana-Mississippi Salt Basins  ...   44.672   187.68    NaN
# 60343  Louisiana-Mississippi Salt Basins  ...   50.256   218.96    NaN
# 60344  Louisiana-Mississippi Salt Basins  ...  396.464   191.59    NaN
# 60345  Louisiana-Mississippi Salt Basins  ...    5.584   512.21    NaN
# 60346  Louisiana-Mississippi Salt Basins  ...   11.168   821.10    NaN
#
#             Mg        Na SO4        Sr  Zn  CHARGEBAL  BASIN_CATEGORY
# 224    1170.00  46800.00 NaN  1802.000 NaN       -4.1      Gulf Coast
# 225     805.00  29700.00 NaN  1105.000 NaN       -2.7      Gulf Coast
# 226     325.00  34000.00 NaN  1552.000 NaN        2.1      Gulf Coast
# 227     202.00  22900.00 NaN   854.000 NaN        0.4      Gulf Coast
# 228     360.00  19300.00 NaN   868.000 NaN        0.3      Gulf Coast
# ...        ...       ...  ..       ...  ..        ...             ...
# 60342   422.82  29772.05 NaN   245.336 NaN       -7.3      Gulf Coast
# 60343   478.71  37128.85 NaN   245.336 NaN       -5.3      Gulf Coast
# 60344   391.23  30024.94 NaN   192.764 NaN      -11.4      Gulf Coast
# 60345   571.05  40002.60 NaN   219.050 NaN        1.2      Gulf Coast
# 60346   383.94  51773.48 NaN   201.526 NaN        2.8      Gulf Coast
#
# [14545 rows x 34 columns]

# %%
# Show how many null values each feature has
df_gulf.isnull().sum()
# Out:
# IDUSGS                0
# PLAYTYPE              0
# WELLTYPE              0
# FORMSIMPLE            0
# TDS                   0
# LATITUDE              0
# LONGITUDE             0
# STATE                 0
# COUNTY              414
# PROVINCE              0
# REGION                0
# WELLNAME            189
# API                7326
# DEPTHUPPER         2869
# DEPTHLOWER         3728
# PERIOD             5571
# DATESAMPLE         1485
# PH                 2051
# B                 13698
# Ba                11119
# Br                13469
# HCO3               1981
# Ca                   32
# Cl                    0
# FeTot              9391
# K                     0
# Li                13657
# Mg                  144
# Na                    0
# SO4                4096
# Sr                12869
# Zn                14228
# CHARGEBAL             0
# BASIN_CATEGORY        0
# dtype: int64

# %%
# Drop all non numeric columns

df_gulf = df_gulf.select_dtypes(include=["number"])

# Print the updated DataFrame
df_gulf
# Out:
#        IDUSGS       TDS  LATITUDE  LONGITUDE           API  DEPTHUPPER  \
# 224      1013  171306.0  29.03000  -97.85000  4.225500e+13     10906.0
# 225      1014  109938.0  29.01000  -97.90000  4.225500e+13     10853.0
# 226      1016  108400.0  28.63367  -97.98417  4.202530e+13     13624.0
# 227      1017   71265.0  28.59220  -98.03431  4.202530e+13     13690.0
# 228      1018   71138.0  28.74400  -97.90900  4.225530e+13     13033.0
# ...       ...       ...       ...        ...           ...         ...
# 60342  115346   89456.0  31.59986  -92.15279  1.705925e+13         NaN
# 60343  115347  108691.0  31.48436  -92.00514  1.702521e+13         NaN
# 60344  115348   95434.0  31.49222  -92.00539  1.702521e+13         NaN
# 60345  115350  108019.0  31.47478  -91.87311  1.702522e+13         NaN
# 60346  115351  136668.0  31.37490  -91.80560  1.702501e+13         NaN
#
#          DEPTHLOWER   PH        B       Ba  ...         Cl    FeTot        K  \
# 224    10920.000000  NaN      NaN   25.200  ...  107200.00      NaN  2410.00
# 225    10853.000000  NaN  128.000   25.200  ...   68100.00      NaN  1510.00
# 226    14002.000000  NaN      NaN      NaN  ...   64400.00      NaN  1271.00
# 227    13778.000000  NaN      NaN   66.800  ...   42800.00      NaN   494.00
# 228    13288.000000  NaN      NaN      NaN  ...   43500.00      NaN   340.00
# ...             ...  ...      ...      ...  ...        ...      ...      ...
# 60342   3976.049996  6.8   15.134  219.728  ...   57358.10   44.672   187.68
# 60343   4832.021152  6.7   16.215  164.796  ...   68737.55   50.256   218.96
# 60344   4795.931912  6.0   12.972  123.597  ...   62817.40  396.464   191.59
# 60345   4817.913540  5.2   16.215  123.597  ...   65015.30    5.584   512.21
# 60346   6368.110440  5.3   17.296  260.927  ...   80967.80   11.168   821.10
#
#           Li       Mg        Na  SO4        Sr  Zn  CHARGEBAL
# 224    124.0  1170.00  46800.00  NaN  1802.000 NaN       -4.1
# 225     77.3   805.00  29700.00  NaN  1105.000 NaN       -2.7
# 226      NaN   325.00  34000.00  NaN  1552.000 NaN        2.1
# 227     83.9   202.00  22900.00  NaN   854.000 NaN        0.4
# 228      NaN   360.00  19300.00  NaN   868.000 NaN        0.3
# ...      ...      ...       ...  ...       ...  ..        ...
# 60342    NaN   422.82  29772.05  NaN   245.336 NaN       -7.3
# 60343    NaN   478.71  37128.85  NaN   245.336 NaN       -5.3
# 60344    NaN   391.23  30024.94  NaN   192.764 NaN      -11.4
# 60345    NaN   571.05  40002.60  NaN   219.050 NaN        1.2
# 60346    NaN   383.94  51773.48  NaN   201.526 NaN        2.8
#
# [14545 rows x 23 columns]

# %%
# Show how many null values each feature has
df_gulf.isnull().sum()
# Out:
# IDUSGS            0
# TDS               0
# LATITUDE          0
# LONGITUDE         0
# API            7326
# DEPTHUPPER     2869
# DEPTHLOWER     3728
# PH             2051
# B             13698
# Ba            11119
# Br            13469
# HCO3           1981
# Ca               32
# Cl                0
# FeTot          9391
# K                 0
# Li            13657
# Mg              144
# Na                0
# SO4            4096
# Sr            12869
# Zn            14228
# CHARGEBAL         0
# dtype: int64

# %%
# Create a new dataframe named df_gulf_clean with only columns (PH, HC03, Ca, Cl, K, KNa, Li, Mh, Na, So4, CHARGEBAL) from df_gulf

df_gulf_clean = df_gulf[["PH", "HCO3", "Ca", "Cl", "K", "Li", "Mg", "Na", "SO4", "CHARGEBAL"]]
df_gulf_clean
# Out:
#         PH     HCO3         Ca         Cl        K     Li       Mg        Na  \
# 224    NaN      NaN  11156.000  107200.00  2410.00  124.0  1170.00  46800.00
# 225    NaN      NaN   8080.000   68100.00  1510.00   77.3   805.00  29700.00
# 226    NaN      NaN   6510.000   64400.00  1271.00    NaN   325.00  34000.00
# 227    NaN      NaN   3479.000   42800.00   494.00   83.9   202.00  22900.00
# 228    NaN      NaN   6770.000   43500.00   340.00    NaN   360.00  19300.00
# ...    ...      ...        ...        ...      ...    ...      ...       ...
# 60342  6.8   70.438   1110.216   57358.10   187.68    NaN   422.82  29772.05
# 60343  6.7   33.080   1567.128   68737.55   218.96    NaN   478.71  37128.85
# 60344  6.0  104.393   1258.512   62817.40   191.59    NaN   391.23  30024.94
# 60345  5.2      NaN   1474.944   65015.30   512.21    NaN   571.05  40002.60
# 60346  5.3   17.219   2120.232   80967.80   821.10    NaN   383.94  51773.48
#
#        SO4  CHARGEBAL
# 224    NaN       -4.1
# 225    NaN       -2.7
# 226    NaN        2.1
# 227    NaN        0.4
# 228    NaN        0.3
# ...    ...        ...
# 60342  NaN       -7.3
# 60343  NaN       -5.3
# 60344  NaN      -11.4
# 60345  NaN        1.2
# 60346  NaN        2.8
#
# [14545 rows x 10 columns]

# %%
# Show how many null values each feature has
df_gulf_clean.isnull().sum()
# Out:
# PH            2051
# HCO3          1981
# Ca              32
# Cl               0
# K                0
# Li           13657
# Mg             144
# Na               0
# SO4           4096
# CHARGEBAL        0
# dtype: int64

# %%
# Drop columns with any null values unless they are in column "Li"

df_gulf_clean.dropna(axis=0, how='any', subset=df_gulf_clean.columns.difference(['Li']), inplace=True)
# Out:
# <ipython-input-12-6cb0febe28d5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gulf_clean.dropna(axis=0, how='any', subset=df_gulf_clean.columns.difference(['Li']), inplace=True)

# %%
# Check data types
df_gulf_clean.dtypes
# Out:
# PH           float64
# HCO3         float64
# Ca           float64
# Cl           float64
# K            float64
# Li           float64
# Mg           float64
# Na           float64
# SO4          float64
# CHARGEBAL    float64
# dtype: object

# %%
# Fill in remaining null values with 0's
df_gulf_clean.fillna(0, inplace=True)
# Out:
# <ipython-input-14-47a98ea685b0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gulf_clean.fillna(0, inplace=True)

# %%
# Separate faetures and variable
X = df_gulf_clean.drop(columns=['Li'])
y = df_gulf_clean['Li']

# %%
# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
# Scaling the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Building the neural network model
nn_model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation= 'relu')  # Output layer
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compiling the model
nn_model.compile(optimizer='adam', loss='mean_squared_error', metrics=["accuracy"] )

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,753 (10.75 KB)
#  Trainable params: 2,753 (10.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Run 50 epochs on the model
history = nn_model.fit(X_train_scaled, y_train, epochs=50, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9744 - loss: 300.8589 - val_accuracy: 0.9718 - val_loss: 2935.9033
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9694 - loss: 517.7240 - val_accuracy: 0.9704 - val_loss: 2935.9038
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9702 - loss: 739.0480 - val_accuracy: 0.8577 - val_loss: 2907.8005
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8369 - loss: 656.8790 - val_accuracy: 0.9394 - val_loss: 2732.8071
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8988 - loss: 796.3411 - val_accuracy: 0.9056 - val_loss: 2673.2610
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9288 - loss: 458.3424 - val_accuracy: 0.9493 - val_loss: 2677.7266
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9074 - loss: 933.6184 - val_accuracy: 0.9507 - val_loss: 2666.3345
# Epoch 8/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9442 - loss: 295.1331 - val_accuracy: 0.9324 - val_loss: 2643.4883
# Epoch 9/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9356 - loss: 394.1925 - val_accuracy: 0.9394 - val_loss: 2645.5256
# Epoch 10/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9398 - loss: 607.5294 - val_accuracy: 0.9465 - val_loss: 2653.8696
# Epoch 11/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9344 - loss: 667.2324 - val_accuracy: 0.9352 - val_loss: 2635.8464
# Epoch 12/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9232 - loss: 853.3917 - val_accuracy: 0.9352 - val_loss: 2630.4048
# Epoch 13/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9366 - loss: 620.1899 - val_accuracy: 0.9282 - val_loss: 2623.8848
# Epoch 14/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9378 - loss: 306.8068 - val_accuracy: 0.9620 - val_loss: 2700.5183
# Epoch 15/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9613 - loss: 856.2166 - val_accuracy: 0.9549 - val_loss: 2651.3684
# Epoch 16/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9657 - loss: 841.9824 - val_accuracy: 0.9563 - val_loss: 2649.1724
# Epoch 17/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9603 - loss: 1389.7577 - val_accuracy: 0.9549 - val_loss: 2640.6799
# Epoch 18/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9669 - loss: 237.7267 - val_accuracy: 0.9563 - val_loss: 2635.0852
# Epoch 19/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9655 - loss: 1688.0745 - val_accuracy: 0.9563 - val_loss: 2631.0295
# Epoch 20/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9628 - loss: 245.9367 - val_accuracy: 0.9507 - val_loss: 2611.8938
# Epoch 21/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9596 - loss: 279.3751 - val_accuracy: 0.9648 - val_loss: 2688.6921
# Epoch 22/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9666 - loss: 331.9761 - val_accuracy: 0.9606 - val_loss: 2651.6726
# Epoch 23/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9692 - loss: 797.7603 - val_accuracy: 0.9577 - val_loss: 2616.6033
# Epoch 24/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9652 - loss: 483.3713 - val_accuracy: 0.9577 - val_loss: 2630.9023
# Epoch 25/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9687 - loss: 417.6266 - val_accuracy: 0.9606 - val_loss: 2644.6824
# Epoch 26/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9678 - loss: 332.0659 - val_accuracy: 0.9577 - val_loss: 2595.2339
# Epoch 27/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9616 - loss: 716.9816 - val_accuracy: 0.9592 - val_loss: 2610.6765
# Epoch 28/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9660 - loss: 397.9551 - val_accuracy: 0.9662 - val_loss: 2676.8752
# Epoch 29/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9713 - loss: 369.3686 - val_accuracy: 0.9634 - val_loss: 2620.4316
# Epoch 30/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9686 - loss: 392.8665 - val_accuracy: 0.9648 - val_loss: 2640.9365
# Epoch 31/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9733 - loss: 128.8094 - val_accuracy: 0.9648 - val_loss: 2618.8704
# Epoch 32/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9686 - loss: 1807.5627 - val_accuracy: 0.9606 - val_loss: 2592.8557
# Epoch 33/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9652 - loss: 309.2883 - val_accuracy: 0.9662 - val_loss: 2657.3240
# Epoch 34/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9672 - loss: 878.8395 - val_accuracy: 0.9620 - val_loss: 2578.4739
# Epoch 35/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9672 - loss: 862.8170 - val_accuracy: 0.9662 - val_loss: 2658.3633
# Epoch 36/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9678 - loss: 217.9627 - val_accuracy: 0.9690 - val_loss: 2698.1975
# Epoch 37/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9703 - loss: 370.2154 - val_accuracy: 0.9662 - val_loss: 2604.3618
# Epoch 38/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9679 - loss: 92.1985 - val_accuracy: 0.9690 - val_loss: 2687.9451
# Epoch 39/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9674 - loss: 673.6417 - val_accuracy: 0.9648 - val_loss: 2555.0930
# Epoch 40/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9673 - loss: 522.2274 - val_accuracy: 0.9676 - val_loss: 2670.5610
# Epoch 41/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9710 - loss: 304.5836 - val_accuracy: 0.9634 - val_loss: 2546.7295
# Epoch 42/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9658 - loss: 522.8772 - val_accuracy: 0.9634 - val_loss: 2550.2446
# Epoch 43/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9671 - loss: 514.1426 - val_accuracy: 0.9648 - val_loss: 2570.4387
# Epoch 44/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9718 - loss: 747.7288 - val_accuracy: 0.9634 - val_loss: 2520.2710
# Epoch 45/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9695 - loss: 843.5617 - val_accuracy: 0.9662 - val_loss: 2615.2061
# Epoch 46/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9709 - loss: 133.6992 - val_accuracy: 0.9634 - val_loss: 2502.4839
# Epoch 47/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9700 - loss: 453.5739 - val_accuracy: 0.9704 - val_loss: 2667.1316
# Epoch 48/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9667 - loss: 773.6838 - val_accuracy: 0.9634 - val_loss: 2504.5000
# Epoch 49/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9715 - loss: 1252.5106 - val_accuracy: 0.9704 - val_loss: 2680.4612
# Epoch 50/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9692 - loss: 164.8802 - val_accuracy: 0.9676 - val_loss: 2592.2368

# %%
# Evaluating the model
loss = nn_model.evaluate(X_test_scaled, y_test)
print(f'Test Loss: {loss}')
# Out:
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9678 - loss: 57.4454
# Test Loss: [49.077640533447266, 0.9695431590080261]
